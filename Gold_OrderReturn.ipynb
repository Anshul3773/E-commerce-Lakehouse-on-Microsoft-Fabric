# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark.sql.types import *
# Out:
# StatementMeta(, e07859ba-0f34-4cd6-9591-4eeb97ce1430, 3, Finished, Available, Finished)

# %%
# %%sql
#
# create table if not exists LakeHouse_2.Gold_OrderReturn
# (
#
# Order_ID  string,
# Return string,
# Order_Year int,
# Order_Month int,
# Created_TS TIMESTAMP,
# Modified_TS TIMESTAMP
#
# )
# using delta
# partitioned by(Order_Year,Order_Month)
# Out:
# StatementMeta(, e07859ba-0f34-4cd6-9591-4eeb97ce1430, 4, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
Max_Date=spark.sql("select coalesce(max(Modified_TS),'1900-01-01') from Lakehouse_2.gold_orderreturn").first()[0]
# Out:
# StatementMeta(, e07859ba-0f34-4cd6-9591-4eeb97ce1430, 5, Finished, Available, Finished)

# %%
Max_Date
# Out:
# StatementMeta(, e07859ba-0f34-4cd6-9591-4eeb97ce1430, 6, Finished, Available, Finished)
# '1900-01-01'

# %%
df=spark.sql("""select Order_ID  ,
Return ,
Order_Year, 
Order_Month ,
Created_TS ,
Modified_TS 
from Lakehouse_2.bronze_sales where Return="Yes" and Modified_TS>'{}'""".format(Max_Date))
# Out:
# StatementMeta(, e07859ba-0f34-4cd6-9591-4eeb97ce1430, 7, Finished, Available, Finished)

# %%
df.createOrReplaceTempView("ViewReturn")
# Out:
# StatementMeta(, e07859ba-0f34-4cd6-9591-4eeb97ce1430, 8, Finished, Available, Finished)

# %%
# %%sql
# insert into LakeHouse_2.gold_orderreturn
# select * from ViewReturn
# Out:
# StatementMeta(, e07859ba-0f34-4cd6-9591-4eeb97ce1430, 9, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>
