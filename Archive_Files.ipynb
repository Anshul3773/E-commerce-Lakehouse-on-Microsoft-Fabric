# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from notebookutils import mssparkutils
# Out:
# StatementMeta(, 40b28225-4284-4f41-9e13-d26a2dc82ea7, 3, Finished, Available, Finished)

# %%
mssparkutils.fs.mount("abfss://e9568696-3973-4ead-9553-e45d7886a97e@onelake.dfs.fabric.microsoft.com/f1036687-fcf2-4a53-b856-29b6bd782ea9/Files","/Files")
# Out:
# StatementMeta(, 40b28225-4284-4f41-9e13-d26a2dc82ea7, 5, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, bc29fa17-1174-447d-bcb6-52435486c843)
# True

# %%
mssparkutils.fs.getMountPath("/Files")
# Out:
# StatementMeta(, 40b28225-4284-4f41-9e13-d26a2dc82ea7, 6, Finished, Available, Finished)
# '/synfs/notebook/40b28225-4284-4f41-9e13-d26a2dc82ea7/Files'

# %%
check_files=mssparkutils.fs.ls(f"file://{mssparkutils.fs.getMountPath('/Files')}/Current/")
# Out:
# StatementMeta(, 40b28225-4284-4f41-9e13-d26a2dc82ea7, 7, Finished, Available, Finished)

# %%
for file in check_files:
    if file.path:
        mssparkutils.fs.mv(file.path,f"file://{mssparkutils.fs.getMountPath('/Files')}/Archive/")
# Out:
# StatementMeta(, 40b28225-4284-4f41-9e13-d26a2dc82ea7, 8, Finished, Available, Finished)
