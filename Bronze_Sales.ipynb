# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark.sql.types import *
import pandas as pd
# Out:
# StatementMeta(, d13e7d28-7c65-4123-9b2a-f03dd90caeaf, 3, Finished, Available, Finished)

# %%
df_sales= pd.read_excel("abfss://e9568696-3973-4ead-9553-e45d7886a97e@onelake.dfs.fabric.microsoft.com/f1036687-fcf2-4a53-b856-29b6bd782ea9/Files/Current/Sales*.xlsx",sheet_name="Sales")
# Out:
# StatementMeta(, d13e7d28-7c65-4123-9b2a-f03dd90caeaf, 4, Finished, Available, Finished)

# %%
df1=spark.createDataFrame(df_sales)
# Out:
# StatementMeta(, d13e7d28-7c65-4123-9b2a-f03dd90caeaf, 5, Finished, Available, Finished)

# %%
display(df1.head(10))
# Out:
# StatementMeta(, d13e7d28-7c65-4123-9b2a-f03dd90caeaf, 6, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, faa54bbe-211d-4508-bf2c-2b5741138d92)

# %%
df_Returns= pd.read_excel("abfss://e9568696-3973-4ead-9553-e45d7886a97e@onelake.dfs.fabric.microsoft.com/f1036687-fcf2-4a53-b856-29b6bd782ea9/Files/Current/Sales*.xlsx",sheet_name="Returns")
# Out:
# StatementMeta(, d13e7d28-7c65-4123-9b2a-f03dd90caeaf, 7, Finished, Available, Finished)

# %%
df2=spark.createDataFrame(df_Returns)
# Out:
# StatementMeta(, d13e7d28-7c65-4123-9b2a-f03dd90caeaf, 8, Finished, Available, Finished)

# %%
display(df2.head(10))
# Out:
# StatementMeta(, d13e7d28-7c65-4123-9b2a-f03dd90caeaf, 9, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, bd0d4bab-c743-4605-9da8-7c77f1d9ad43)

# %%
df_final=df1.join(df2,df1.Order_ID==df2.Order_ID,how="left").drop(df2.Order_ID,df2.Customer_Name,df2.Sales_Amount)
# Out:
# StatementMeta(, d13e7d28-7c65-4123-9b2a-f03dd90caeaf, 10, Finished, Available, Finished)

# %%
df_mod=df_final.withColumns({"Order_Year": year("Order_Date"), \
                "Order_Month": month("Order_Date"), \
                "Created_TS": current_timestamp(),\
                "Modified_TS": current_timestamp(),\
                })
# Out:
# StatementMeta(, d13e7d28-7c65-4123-9b2a-f03dd90caeaf, 11, Finished, Available, Finished)

# %%
#view to load data in the bronze layer
df_mod.createOrReplaceTempView("ViewSales")
# Out:
# StatementMeta(, d13e7d28-7c65-4123-9b2a-f03dd90caeaf, 12, Finished, Available, Finished)

# %%
# %%sql
# create table if not exists LakeHouse_2.Bronze_Sales
# (
#     Order_ID	string,
#     Order_Date	Date,
#     Shipping_Date	date,
#     Aging	int,
#     Ship_Mode	string,
#     Product_Category	string,
#     Product	 string,
#     Sales 	float,
#     Quantity	float,
#     Discount	 float,
#     Profit 	 float,
#     Shipping_Cost 	float,
#     Order_Priority	string,
#     Customer_ID	string,
#     Customer_Name	string,
#     Segment	string,
#     City	string,
#     State	string,
#     Country	string,
#     Region string,
# 	Return string,
#     Order_Year int,
#     Order_Month int,
#     Created_TS  TIMESTAMP,
#     Modified_TS  TIMESTAMP
# )
# using DELTA
# PARTITIONED by(Order_Year,Order_Month)
# Out:
# StatementMeta(, d13e7d28-7c65-4123-9b2a-f03dd90caeaf, 16, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# Merge into LakeHouse_2.Bronze_Sales as BS
# using ViewSales as VS
# on  BS.Order_Year=VS.Order_Year and BS.Order_Month=VS.Order_Month and BS.Order_ID=VS.Order_ID
# when matched then
# update SET
# BS.Order_Date	=	VS.Order_Date	,
# BS.Shipping_Date	=	VS.Shipping_Date	,
# BS.Aging	=	VS.Aging	,
# BS.Ship_Mode	=	VS.Ship_Mode	,
# BS.Product_Category	=	VS.Product_Category	,
# BS.Product	=	VS.Product	,
# BS.Sales 	=	VS.Sales 	,
# BS.Quantity	=	VS.Quantity	,
# BS.Discount	=	VS.Discount	,
# BS.Profit 	=	VS.Profit 	,
# BS.Shipping_Cost 	=	VS.Shipping_Cost 	,
# BS.Order_Priority	=	VS.Order_Priority	,
# BS.Customer_ID	=	VS.Customer_ID	,
# BS.Customer_Name	=	VS.Customer_Name	,
# BS.Segment	=	VS.Segment	,
# BS.City	=	VS.City	,
# BS.State	=	VS.State	,
# BS.Country	=	VS.Country	,
# BS.Region  	=	VS.Region  	,
# BS.Return  	=	VS.Return  	,
# BS.Modified_TS	=	VS.Modified_TS
#
# when not matched then
# INSERT
# (
# BS.Order_ID,
# BS.Order_Date	,
# BS.Shipping_Date	,
# BS.Aging	,
# BS.Ship_Mode	,
# BS.Product_Category	,
# BS.Product	,
# BS.Sales 	,
# BS.Quantity	,
# BS.Discount	,
# BS.Profit 	,
# BS.Shipping_Cost 	,
# BS.Order_Priority	,
# BS.Customer_ID	,
# BS.Customer_Name	,
# BS.Segment	,
# BS.City	,
# BS.State	,
# BS.Country	,
# BS.Region  	,
# BS.Return,
# BS.Order_Year  	,
# BS.Order_Month  	,
# BS.Created_TS   	,
# BS.Modified_TS
# )
# values
# (
# VS.Order_ID,
# VS.Order_Date	,
# VS.Shipping_Date	,
# VS.Aging	,
# VS.Ship_Mode	,
# VS.Product_Category	,
# VS.Product	,
# VS.Sales 	,
# VS.Quantity	,
# VS.Discount	,
# VS.Profit 	,
# VS.Shipping_Cost 	,
# VS.Order_Priority	,
# VS.Customer_ID	,
# VS.Customer_Name	,
# VS.Segment	,
# VS.City	,
# VS.State	,
# VS.Country	,
# VS.Region  	,
# VS.Return,
# VS.Order_Year  	,
# VS.Order_Month  	,
# VS.Created_TS   	,
# VS.Modified_TS
#
# )
# Out:
# StatementMeta(, d13e7d28-7c65-4123-9b2a-f03dd90caeaf, 17, Finished, Available, Finished)
# <Spark SQL result set with 1 rows and 4 fields>

# %%
# %%sql
# Select * From LakeHouse_2.bronze_sales limit(10)
# Out:
# StatementMeta(, d13e7d28-7c65-4123-9b2a-f03dd90caeaf, 18, Finished, Available, Finished)
# <Spark SQL result set with 10 rows and 25 fields>
