# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from notebookutils import mssparkutils
# Out:
# StatementMeta(, bdcad1ce-c1eb-4448-bb7c-f0af48280e1f, 3, Finished, Available, Finished)

# %%
mssparkutils.fs.mount("abfss://e9568696-3973-4ead-9553-e45d7886a97e@onelake.dfs.fabric.microsoft.com/f1036687-fcf2-4a53-b856-29b6bd782ea9/Files","/Files")
# Out:
# StatementMeta(, bdcad1ce-c1eb-4448-bb7c-f0af48280e1f, 4, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 575d153f-03b9-4687-955f-85cc676f3fef)
# True

# %%
mssparkutils.fs.getMountPath("/Files")
# Out:
# StatementMeta(, bdcad1ce-c1eb-4448-bb7c-f0af48280e1f, 5, Finished, Available, Finished)
# '/synfs/notebook/bdcad1ce-c1eb-4448-bb7c-f0af48280e1f/Files'

# %%
check_files=mssparkutils.fs.ls(f"file://{mssparkutils.fs.getMountPath('/Files')}/Current/")
# Out:
# StatementMeta(, bdcad1ce-c1eb-4448-bb7c-f0af48280e1f, 6, Finished, Available, Finished)

# %%
if check_files:
    mssparkutils.notebook.run("Bronze_Sales")
    mssparkutils.notebook.run("Gold_Customer")
    mssparkutils.notebook.run("Gold_Date")
    mssparkutils.notebook.run("Gold_Product")
    mssparkutils.notebook.run("Gold_ShipMode")
    mssparkutils.notebook.run("Gold_OrderPriority")
    mssparkutils.notebook.run("Gold_OrderReturn")
    mssparkutils.notebook.run("Gold_Fact_Sale")
    mssparkutils.notebook.run("Archive_Files")
# Out:
# StatementMeta(, bdcad1ce-c1eb-4448-bb7c-f0af48280e1f, 9, Finished, Available, Finished)
